# %%
# !pip install gi
# !pip install seaborn
# !pip install pandas
# Out:
# ERROR: Could not find a version that satisfies the requirement gi (from versions: none)
# ERROR: No matching distribution found for gi
# ...

# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("www.datos.gov.co",
                 "yTUjZHEoxbSvQpm39CYGQPuU8")## Cambie token_aqui por el token recien creado

# %%
#Sede_Principal_ESAP: 899999054
# Antioquia: 800117519
# Atlántico_Cesar_Magdalena_La_Guajira: 800117522
# Bolivar_Córdoba_Sucre_San Andrés: 800248529
# Boyacá_Casanare: 800117524
# Caldas: 800117525
# Cauca: 800117528
# Cundinamarca: 830011682
# Huila_Caquetá_Putumayo: 813006956
# Meta_Guainía_Guaviare_Vaupés_Vichada_Amazonas: 800117530
# Nariño_Alto Putumayo: 800117534
# Norte_Santander - Arauca: 800145876
# Quindío_Risaralda: 800117537
# Santander: 800117540
# Tolima: 800117541
# Valle: 800117545

# %%
socrata_dataset_identifier = "jbjy-vk9h"

Query = """
select 
    *
where
    fecha_de_firma >= '2020-01-01'
    and
    nit_entidad IN ("899999054", "800117530","800117519","800117522","800248529","800117524","800117525","800117537","800117528","830011682","813006956","800117530","800117534","800145876","800117537","800117540","800117541","800117545")
limit
1000000
"""

contratos_2020 = client.get(socrata_dataset_identifier, content_type="json", query=Query)

secopII_2020_DF = pd.DataFrame(pd.DataFrame.from_dict(contratos_2020))
secopII_2020_DF
# Out:
#                                    nombre_entidad nit_entidad  \
# 0                      ESAP TERRITORIAL ANTIOQUIA   800117519
# 1                      ESAP TERRITORIAL ANTIOQUIA   800117519
# 2                      ESAP TERRITORIAL ANTIOQUIA   800117519
# 3                      ESAP TERRITORIAL ANTIOQUIA   800117519
# 4                      ESAP TERRITORIAL ANTIOQUIA   800117519
# ...                                           ...         ...
# 14001  ESCUELA SUPERIOR DE ADMINISTRACIÓN PUBLICA   899999054
# 14002  ESCUELA SUPERIOR DE ADMINISTRACIÓN PUBLICA   899999054
# 14003  ESCUELA SUPERIOR DE ADMINISTRACIÓN PUBLICA   899999054
# 14004  ESCUELA SUPERIOR DE ADMINISTRACIÓN PUBLICA   899999054
# 14005  ESCUELA SUPERIOR DE ADMINISTRACIÓN PUBLICA   899999054
#
#                      departamento    ciudad                      localizaci_n  \
# 0                       Antioquia  Medellín  Colombia,  Antioquia ,  Medellín
# ...

# %%
secopII_2020_DF.to_csv('../../datos/Raw/contratos_secop_esap.csv')
