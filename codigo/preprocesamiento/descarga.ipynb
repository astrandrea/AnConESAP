# %%
#!pip install sodapy
#!pip install seaborn
#!pip install pandas

# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("www.datos.gov.co",
                 "yTUjZHEoxbSvQpm39CYGQPuU8")## Cambie token_aqui por el token recien creado

# %%
socrata_dataset_identifier = "jbjy-vk9h"

Query = """
select 
    *
where
    fecha_de_firma >= '2020-01-01'
    and
    nit_entidad = 899999054
limit
1000000
"""

contratosESAP_2020 = client.get(socrata_dataset_identifier, content_type="json", query=Query)

DF_contratosESAP_2020 = pd.DataFrame(pd.DataFrame.from_dict(contratos_2022))
DF_contratosESAP_2020
# Out:
#                                   nombre_entidad nit_entidad  \
# 0     ESCUELA SUPERIOR DE ADMINISTRACIÓN PUBLICA   899999054
# 1     ESCUELA SUPERIOR DE ADMINISTRACIÓN PUBLICA   899999054
# 2     ESCUELA SUPERIOR DE ADMINISTRACIÓN PUBLICA   899999054
# 3     ESCUELA SUPERIOR DE ADMINISTRACIÓN PUBLICA   899999054
# 4     ESCUELA SUPERIOR DE ADMINISTRACIÓN PUBLICA   899999054
# ...                                          ...         ...
# 4927  ESCUELA SUPERIOR DE ADMINISTRACIÓN PUBLICA   899999054
# 4928  ESCUELA SUPERIOR DE ADMINISTRACIÓN PUBLICA   899999054
# 4929  ESCUELA SUPERIOR DE ADMINISTRACIÓN PUBLICA   899999054
# 4930  ESCUELA SUPERIOR DE ADMINISTRACIÓN PUBLICA   899999054
# 4931  ESCUELA SUPERIOR DE ADMINISTRACIÓN PUBLICA   899999054
#
#                     departamento  ciudad              localizaci_n     orden  \
# 0     Distrito Capital de Bogotá  Bogotá  Colombia, Bogotá, Bogotá  Nacional
# ...

# %%
DF_contratosESAP_2020.to_csv('../../datos/Raw/contratos_secop_2020.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\Astrandrea\Documents\AnaConESAP\codigo\preprocesamiento\descarga.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Astrandrea/Documents/AnaConESAP/codigo/preprocesamiento/descarga.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> DF_contratosESAP_2020.to_csv('../../Datos/Raw/contratos_secop_2020.csv')
#
# File c:\Users\Astrandrea\miniconda3\envs\mine\Lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
# ...

# %%
DF_contratosESAP_2020.to_csv('C:/full/path/to/datos/Raw/contratos_secop_2020.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\Astrandrea\Documents\AnaConESAP\codigo\preprocesamiento\descarga.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Astrandrea/Documents/AnaConESAP/codigo/preprocesamiento/descarga.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> DF_contratosESAP_2020.to_csv('C:/full/path/to/datos/Raw/contratos_secop_2020.csv')
#
# File c:\Users\Astrandrea\miniconda3\envs\mine\Lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
# ...
